# %% [markdown]
# ### Importing the needed libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Loading the data sets

# %%
m1_customers= pd.read_json("C:/Users/DELL/Desktop/Trestle DE/repos/e-commerce-data-pipeline/Data\Market 1 Customers.json")
m1_customers.head()
# Out:
#    Customer ID Last Used Platform  Is Blocked                Created At  \
# 0      3144837                WEB           0  2021-03-15T17:13:19.000Z
# 1      3174590                WEB           0  2021-03-20T14:15:11.000Z
# 2      3181998                WEB           0  2021-03-21T15:36:51.000Z
# 3      3191244                WEB           0  2021-03-23T08:54:00.000Z
# 4      3274222                WEB           0  2021-04-06T13:52:39.000Z
#
#   Language  Outstanding Amount  Loyalty Points  Number of employees
# 0       en                   0               0                  NaN
# 1       en                   0               0                  NaN
# 2       en                   0               0                  NaN
# 3       en                   0             367                  NaN
# 4       en                   0               0                  NaN

# %%
m1_deliveries= pd.read_csv("C:/Users/DELL/Desktop/Trestle DE/repos/e-commerce-data-pipeline/Data\Market 1 Deliveries.csv")
m1_deliveries.head()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (12,14,16,19,30,31) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#      Task_ID       Order_ID  Relationship     Team_Name Task_Type  \
# 0  357410575  YR-10691280,0  3.570000e+29  Default Team  Delivery
# 1  357410575  YR-10691280,0  3.570000e+29  Default Team  Delivery
# 2  303698961   YR-8221753,0  3.040000e+29  Default Team  Delivery
# 3  302906575   YR-8133470,0  3.030000e+29  Default Team  Delivery
# 4  302906575   YR-8133470,0  3.030000e+29  Default Team  Delivery
#
#                                       Notes  \
# 0  Deliver tomorrow morning by 8.00a.m note
# 1  Deliver tomorrow morning by 8.00a.m note
# 2               To be delivered today by 12
# 3                              DELIVER BY 6
# 4                              DELIVER BY 6
#
# ...

# %%
m1_orders= pd.read_csv("C:/Users/DELL/Desktop/Trestle DE/repos/e-commerce-data-pipeline/Data\Market 1 Orders.csv")
m1_orders.head()
# Out:
#    Order ID Order Status       Category Name         SKU  Customization Group  \
# 0  11265015      ORDERED   Cooking Fat & Oil    KKCO0487                  NaN
# 1  11264651      ORDERED  Cleaning & Hygiene  KKPT280100                  NaN
# 2  11264651      ORDERED       Flour & Sugar    KKFS0702                  NaN
# 3  11264651      ORDERED    Salt & Seasoning    KKSS0002                  NaN
# 4  11264651      ORDERED           Beverages    KKBE0105                  NaN
#
#    Customization Option  Quantity  Unit Price Cost Price Total Cost Price  \
# 0                   NaN         1        4400       4250             4250
# 1                   NaN         1         180        130              130
# 2                   NaN         6         263        247             1482
# 3                   NaN        10          65         58              580
# 4                   NaN         1         249      208.5            208.5
#
# ...

# %%
m2_customers= pd.read_json("C:/Users/DELL/Desktop/Trestle DE/repos/e-commerce-data-pipeline/Data\Market 2 Customers.json")
m2_customers.head()
# Out:
#    Customer ID Last Used Platform  Is Blocked                Created At  \
# 0      3922702                WEB           0  2021-07-12T08:06:47.000Z
# 1      4058001                WEB           0  2021-08-05T08:22:35.000Z
# 2      4058334                WEB           0  2021-08-05T09:38:09.000Z
# 3      4058414                WEB           0  2021-08-05T09:56:57.000Z
# 4      4058431                WEB           0  2021-08-05T09:59:51.000Z
#
#   Language  Outstanding Amount  Loyalty Points  Number of Employees
# 0       en                   0               0                  NaN
# 1       en                   0               0                  NaN
# 2       en                   0               0                  NaN
# 3       en                   0               0                  NaN
# 4       en                   0               0                  NaN

# %%
m2_deliveries= pd.read_csv("C:/Users/DELL/Desktop/Trestle DE/repos/e-commerce-data-pipeline/Data\Market 2 Deliveries.csv")
m2_deliveries.head()
# Out:
#      Task_ID       Order_ID  Relationship     Team_Name Task_Type Notes  \
# 0  368032956  YR-11262518,0  3.680000e+29  Default Team  Delivery   NaN
# 1  368032956  YR-11262518,0  3.680000e+29  Default Team  Delivery   NaN
# 2  368012178  YR-11261796,0  3.680000e+29  Default Team  Delivery   NaN
# 3  368012178  YR-11261796,0  3.680000e+29  Default Team  Delivery   NaN
# 4  367999205  YR-11261341,0  3.680000e+29  Default Team  Delivery   NaN
#
#   Agent_ID Distance(m) Total_Time_Taken(min) Task_Status  ...  \
# 0  1150142           -                     -    Assigned  ...
# 1  1150142           -                     -    Assigned  ...
# 2  1166840          11                     -  In Transit  ...
# 3  1166840          11                     -  In Transit  ...
# 4  1233220           -                     -    Assigned  ...
#
#   Task_Details_AMOUNT  Special_Instructions     Tip  Delivery_Charges  \
# 0         ₦ 104250.00                     -       -                 -
# ...

# %%
m2_orders= pd.read_csv("C:/Users/DELL/Desktop/Trestle DE/repos/e-commerce-data-pipeline/Data\Market 2 Orders.csv")
m2_orders.head()
# Out:
#    Order ID Order Status  Category Name       SKU  Customization Group  \
# 0  11262518      ORDERED  Flour & Sugar  KNFS0001                  NaN
# 1  11262518      ORDERED        Spreads  KNSP2001                  NaN
# 2  11261796   DISPATCHED  Flour & Sugar  KNFS0001                  NaN
# 3  11261796   DISPATCHED        Spreads  KNSP2001                  NaN
# 4  11261341      ORDERED        Spreads  KNSP2001                  NaN
#
#    Customization Option  Quantity  Unit Price  Cost Price  Total Cost Price  \
# 0                   NaN         5       20850       20370            101850
# 1                   NaN         1         325         300               300
# 2                   NaN         5       20850       20370            101850
# 3                   NaN         1         325         300               300
# 4                   NaN         6         325         300              1800
#
#    ...  Merchant Earning  Commission Amount  Commission Payout Status  \
# ...

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# ### Merging all data

# %%
customers= m1_customers.append(m2_customers, ignore_index=True)
customers.head()
# Out:
#    Customer ID Last Used Platform  Is Blocked                Created At  \
# 0      3144837                WEB           0  2021-03-15T17:13:19.000Z
# 1      3174590                WEB           0  2021-03-20T14:15:11.000Z
# 2      3181998                WEB           0  2021-03-21T15:36:51.000Z
# 3      3191244                WEB           0  2021-03-23T08:54:00.000Z
# 4      3274222                WEB           0  2021-04-06T13:52:39.000Z
#
#   Language  Outstanding Amount  Loyalty Points  Number of employees  \
# 0       en                   0               0                  NaN
# 1       en                   0               0                  NaN
# 2       en                   0               0                  NaN
# 3       en                   0             367                  NaN
# 4       en                   0               0                  NaN
#
#    Number of Employees
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# ...

# %%
deliveries= m1_deliveries.append(m2_deliveries, ignore_index=True)
deliveries.head()
# Out:
#      Task_ID       Order_ID  Relationship     Team_Name Task_Type  \
# 0  357410575  YR-10691280,0  3.570000e+29  Default Team  Delivery
# 1  357410575  YR-10691280,0  3.570000e+29  Default Team  Delivery
# 2  303698961   YR-8221753,0  3.040000e+29  Default Team  Delivery
# 3  302906575   YR-8133470,0  3.030000e+29  Default Team  Delivery
# 4  302906575   YR-8133470,0  3.030000e+29  Default Team  Delivery
#
#                                       Notes  \
# 0  Deliver tomorrow morning by 8.00a.m note
# 1  Deliver tomorrow morning by 8.00a.m note
# 2               To be delivered today by 12
# 3                              DELIVER BY 6
# 4                              DELIVER BY 6
#
#                                             Agent_ID Agent_Name  \
# 0  potatoes should be Medium large enough for Mak...    1280904
# 1  potatoes should be Medium large enough for Mak...    1280904
# 2                                               30pm    1115711
# ...

# %%
orders= m1_orders.append(m2_orders, ignore_index=True)
orders.head()
# Out:
#    Order ID Order Status       Category Name         SKU  Customization Group  \
# 0  11265015      ORDERED   Cooking Fat & Oil    KKCO0487                  NaN
# 1  11264651      ORDERED  Cleaning & Hygiene  KKPT280100                  NaN
# 2  11264651      ORDERED       Flour & Sugar    KKFS0702                  NaN
# 3  11264651      ORDERED    Salt & Seasoning    KKSS0002                  NaN
# 4  11264651      ORDERED           Beverages    KKBE0105                  NaN
#
#    Customization Option  Quantity  Unit Price Cost Price Total Cost Price  \
# 0                   NaN         1        4400       4250             4250
# 1                   NaN         1         180        130              130
# 2                   NaN         6         263        247             1482
# 3                   NaN        10          65         58              580
# 4                   NaN         1         249      208.5            208.5
#
# ...

# %% [markdown]
# ### Checking for columns

# %%
customers_col= list(customers.columns)
customers_col
# Out:
# ['Customer ID',
#  'Last Used Platform',
#  'Is Blocked',
#  'Created At',
#  'Language',
#  'Outstanding Amount',
#  'Loyalty Points',
#  'Number of employees',
#  'Number of Employees']

# %%
deliveries_col= list(deliveries.columns)
deliveries_col
# Out:
# ['Task_ID',
#  'Order_ID',
#  'Relationship',
#  'Team_Name',
#  'Task_Type',
#  'Notes',
#  'Agent_ID',
#  'Agent_Name',
#  'Distance(m)',
#  'Total_Time_Taken(min)',
#  'Task_Status',
#  'Ref_Images',
#  'Rating',
#  'Review',
#  'Latitude',
#  'Longitude',
#  'Tags',
#  'Promo_Applied',
#  'Custom_Template_ID',
#  'Task_Details_QTY',
#  'Task_Details_AMOUNT',
#  'Special_Instructions',
#  'Tip',
#  'Delivery_Charges',
#  'Discount',
#  'Subtotal',
#  'Payment_Type',
#  'Task_Category',
#  'Earning',
#  'Pricing',
#  'Unnamed: 30',
#  'Unnamed: 31']

# %%
orders_col= list(orders.columns)
orders_col
# Out:
# ['Order ID',
#  'Order Status',
#  'Category Name',
#  'SKU',
#  'Customization Group',
#  'Customization Option',
#  'Quantity',
#  'Unit Price',
#  'Cost Price',
#  'Total Cost Price',
#  'Total Price',
#  'Order Total',
#  'Sub Total',
#  'Tax',
#  'Delivery Charge',
#  'Tip',
#  'Discount',
#  'Remaining Balance',
#  'Payment Method',
#  'Additional Charge',
#  'Taxable Amount',
#  'Transaction ID',
#  'Currency Symbol',
#  'Transaction Status',
#  'Promo Code',
#  'Customer ID',
#  'Merchant ID',
#  'Description',
#  'Distance (in km)',
#  'Order Time',
#  'Pickup Time',
#  'Delivery Time',
#  'Ratings',
#  'Reviews',
#  'Merchant Earning',
#  'Commission Amount',
#  'Commission Payout Status',
#  'Order Preparation Time',
#  'Debt Amount',
#  'Redeemed Loyalty Points',
#  'Consumed Loyalty Points',
#  'Cancellation Reason',
#  'Flat Discount',
#  'Checkout Template Name',
#  'Checkout Template Value']
